# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
from google.colab import drive #toimport google drive data

# %%
drive.mount('/content/drive') #to mount the drive data into colab cloud and enter the activation code
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/"My Drive/Long Hour Coding - Rushi/Arjun_Assignment_data"
# Out:
# /content/drive/My Drive/Long Hour Coding - Rushi/Arjun_Assignment_data

# %%
Dataset = pd.read_csv('postLinks.csv')
Dataset
# Out:
#          Unnamed: 0          id            creation_date   post_id  \
# 0                 0          19  2010-04-26T02:59:48.130       109
# 1                 1          37  2010-04-26T02:59:48.600      1970
# 2                 2          42  2010-04-26T02:59:48.647      2154
# 3                 3          48  2010-04-26T02:59:48.740      2483
# 4                 4          52  2010-04-26T02:59:48.757      2572
# ...             ...         ...                      ...       ...
# 5292619     5292619  1624278139  2018-09-02T08:09:41.520  52133002
# 5292620     5292620  1624278147  2018-09-02T08:10:50.820  52134991
# 5292621     5292621  1624278315  2018-09-02T08:14:26.470  52135049
# 5292622     5292622  1624278337  2018-09-02T08:15:36.387  52135007
# 5292623     5292623  1624278449  2018-09-02T08:17:32.137  52135049
#
#          related_post_id  link_type_id
# 0                  32412             1
# 1                 617600             1
# 2                2451138             1
# ...

# %%
Dataset2 = pd.read_csv('posts_short.csv')
Dataset2
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Unnamed: 0        id  post_type_id  accepted_answer_id  parent_id  \
# 0                0         4             1                   7       -999
# 1                1         6             1                  31       -999
# 2                2         9             1                1404       -999
# 3                3        11             1                1248       -999
# 4                4        13             1                -999       -999
# ...            ...       ...           ...                 ...        ...
# 676199      676199  52133457             1                -999       -999
# 676200      676200  52133674             1                -999       -999
# 676201      676201  52133700             1                -999       -999
# ...

# %%
Dataset3 = pd.read_csv('posts_long.csv')
Dataset3
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Unnamed: 0        id  post_type_id  accepted_answer_id  parent_id  \
# 0                0         4             1                   7       -999
# 1                1         6             1                  31       -999
# 2                2         9             1                1404       -999
# 3                3        11             1                1248       -999
# 4                4        13             1                -999       -999
# ...            ...       ...           ...                 ...        ...
# 676199      676199  52133457             1                -999       -999
# 676200      676200  52133674             1                -999       -999
# 676201      676201  52133700             1                -999       -999
# ...

# %%
newList = list()
tag_short=Dataset3.values[:,9]
tagshort2=list()
tags=list()
for i in range(676204):
  x = tag_short[i].split("<")    
  s = "".join(x)
  x = s.split(">")
  x.pop()
  tagshort2.append(x)
  tags.append(len(x))
  for j in x:
    newList.append(j)

# %%
print(len(newList))
# Out:
# 1921047

# %%
tags
# Out:
# [5,
#  4,
#  3,
#  5,
#  5,
#  2,
#  4,
#  3,
#  4,
#  4,
#  4,
#  3,
#  5,
#  4,
#  4,
#  4,
#  4,
#  5,
#  4,
#  4,
#  2,
#  4,
#  3,
#  2,
#  2,
#  3,
#  2,
#  3,
#  5,
#  4,
#  5,
#  4,
#  3,
#  3,
#  3,
#  5,
#  4,
#  4,
#  4,
#  2,
#  2,
#  4,
#  5,
#  4,
#  3,
#  3,
#  5,
#  2,
#  5,
#  3,
#  3,
#  4,
#  2,
#  4,
#  4,
#  5,
#  1,
#  2,
#  1,
#  4,
#  4,
#  2,
#  5,
#  5,
#  5,
#  2,
#  4,
#  5,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  2,
#  4,
#  3,
#  3,
#  3,
#  4,
#  5,
#  3,
#  2,
#  5,
#  2,
#  5,
#  3,
#  5,
#  4,
#  4,
#  1,
#  5,
#  2,
#  2,
#  3,
#  1,
#  2,
#  2,
#  4,
#  2,
#  5,
#  3,
#  2,
#  2,
#  3,
#  2,
#  1,
#  5,
#  3,
#  4,
#  5,
#  4,
#  3,
#  3,
#  1,
#  5,
#  4,
#  4,
#  3,
#  1,
#  3,
#  3,
#  3,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  3,
#  1,
#  1,
#  4,
#  3,
#  5,
#  2,
#  5,
#  4,
#  3,
#  2,
#  2,
#  1,
#  3,
#  2,
#  5,
#  1,
#  3,
#  2,
#  2,
#  2,
#  3,
#  3,
#  2,
#  4,
#  3,
#  1,
#  1,
#  1,
#  4,
#  4,
#  2,
#  4,
#  3,
#  4,
#  4,
#  3,
# ...

# %%
tagshort2
# Out:
# [['c#', 'floating-point', 'type-conversion', 'double', 'decimal'],
#  ['html', 'css', 'css3', 'internet-explorer-7'],
#  ['c#', '.net', 'datetime'],
#  ['c#', 'datetime', 'time', 'datediff', 'relative-time-span'],
#  ['javascript', 'html', 'browser', 'timezone', 'timezoneoffset'],
#  ['.net', 'math'],
#  ['mysql', 'database', 'binary-data', 'data-storage'],
#  ['mysql', 'database', 'triggers'],
#  ['sql', 'sql-server', 'datatable', 'rdbms'],
#  ['php', 'plugins', 'architecture', 'hook'],
#  ['html', 'form-submit', 'html-form', 'submit-button'],
#  ['c#', 'linq', '.net-3.5'],
#  ['linux', 'winapi', 'visual-c++', 'unix', 'timer'],
#  ['svn', 'tortoisesvn', 'branch', 'branching-and-merging'],
#  ['.net', 'performance', 'memory-leaks', 'com-interop'],
#  ['java', 'xml', 'csv', 'data-conversion'],
#  ['java', 'php', 'oop', 'theory'],
#  ['mysql', 'sql-server', 'csv', 'sql-server-2005', 'bcp'],
#  ['sql-server', 'database', 'svn', 'version-control'],
# ...

# %%
#Question 1
import seaborn as sns
plt.figure(figsize=(12,8))
ax=sns.histplot(data="Dataset3",x=tags,color='lightseagreen')
ax.figure.savefig('histo.png', dpi=500,bbox_inches='tight')

# %%
id_short=Dataset3.values[:676204,1]
id_short= id_short.tolist()

# %%
id_short
# Out:
# [4,
#  6,
#  9,
#  11,
#  13,
#  14,
#  17,
#  24,
#  36,
#  42,
#  48,
#  59,
#  88,
#  90,
#  104,
#  123,
#  126,
#  129,
#  173,
#  180,
#  231,
#  260,
#  289,
#  328,
#  336,
#  361,
#  371,
#  402,
#  549,
#  564,
#  588,
#  609,
#  622,
#  626,
#  650,
#  696,
#  709,
#  752,
#  769,
#  773,
#  871,
#  879,
#  888,
#  972,
#  1005,
#  1033,
#  1037,
#  1040,
#  1108,
#  1160,
#  1276,
#  1304,
#  1383,
#  1408,
#  1457,
#  1476,
#  1644,
#  1669,
#  1711,
#  1746,
#  1760,
#  1854,
#  1898,
#  2027,
#  2056,
#  2120,
#  2134,
#  2138,
#  2158,
#  2232,
#  2250,
#  2284,
#  2366,
#  2482,
#  2483,
#  2488,
#  2525,
#  2530,
#  2540,
#  2647,
#  2658,
#  2702,
#  2711,
#  2756,
#  2767,
#  2785,
#  2840,
#  2844,
#  2861,
#  2871,
#  2914,
#  2933,
#  2970,
#  3021,
#  3058,
#  3061,
#  3088,
#  3213,
#  3224,
#  3230,
#  3255,
#  3284,
#  3319,
#  3385,
#  3432,
#  3452,
#  3510,
#  3589,
#  3611,
#  3713,
#  3748,
#  3793,
#  3798,
#  3839,
#  3859,
#  3881,
#  3927,
# ...

# %%
#sns.set_theme(style="whitegrid")

#ax = sns.barplot(x=id_short, y=tags, data=Dataset3)

# %%
#from typing import NewType
#newList = list()
#for i in tag_short:
 # newList.append(i.split('>')[0])
#print(len(newList))

# %%
#newList = [s.replace('<', '') for s in newList]

# %%
x = np.array(newList)
y = np.unique(x)
print(y)
# Out:
# ['.a' '.app' '.aspxauth' ... 'zx81' 'zxing' 'zynq']

# %%
print(len(x))
# Out:
# 1921047

# %%
print(len(y))
# Out:
# 25310

# %%
print(len(newList))
# Out:
# 1921047

# %%
#output = []
#for x in newList:
 #   if x not in output:
  #      output.append(x)
#print(output)

# %%
#print(len(output))

# %%
# initializing the list
random_list = newList
frequency = {}

# iterating over the list
for item in random_list:
   # checking the element in dictionary
   if item in frequency:
      # incrementing the counr
      frequency[item] += 1
   else:
      # initializing the count
      frequency[item] = 1

# printing the frequency
print(frequency)
# Out:
# {'c#': 61899, 'floating-point': 1628, 'type-conversion': 759, 'double': 924, 'decimal': 577, 'html': 33736, 'css': 23161, 'css3': 4629, 'internet-explorer-7': 92, '.net': 14290, 'datetime': 3827, 'time': 1561, 'datediff': 79, 'relative-time-span': 3, 'javascript': 81346, 'browser': 1078, 'timezone': 710, 'timezoneoffset': 44, 'math': 2142, 'mysql': 24765, 'database': 5045, 'binary-data': 47, 'data-storage': 11, 'triggers': 371, 'sql': 17227, 'sql-server': 8165, 'datatable': 518, 'rdbms': 58, 'php': 65333, 'plugins': 284, 'architecture': 222, 'hook': 87, 'form-submit': 97, 'html-form': 80, 'submit-button': 19, 'linq': 3267, '.net-3.5': 274, 'linux': 6944, 'winapi': 1689, 'visual-c++': 1193, 'unix': 2028, 'timer': 702, 'svn': 628, 'tortoisesvn': 105, 'branch': 167, 'branching-and-merging': 15, 'performance': 3022, 'memory-leaks': 461, 'com-interop': 47, 'java': 94846, 'xml': 5981, 'csv': 2370, 'data-conversion': 66, 'oop': 3444, 'theory': 97, 'sql-server-2005': 768, 'bcp': 12, 'version
# ...

# %%
#Determine the top-25 Tags appearing frequently
from collections import Counter
a = Counter(frequency)
 
# Finding 3 highest values
high_25 = a.most_common(25)
 
 
 
print("top-25 Tags")

 
for i in high_25:
    print(i[0]," : ",i[1]," ")
# Out:
# top-25 Tags
# java  :  94846
# javascript  :  81346
# php  :  65333
# c#  :  61899
# python  :  61505
# c++  :  40158
# android  :  39910
# html  :  33736
# jquery  :  32601
# mysql  :  24765
# css  :  23161
# c  :  22166
# ios  :  21583
# arrays  :  19867
# r  :  19744
# sql  :  17227
# .net  :  14290
# regex  :  14107
# string  :  13397
# objective-c  :  12949
# swift  :  11197
# json  :  10705
# iphone  :  9295
# asp.net  :  8276
# sql-server  :  8165

# %%
#Determine the top-500 Tags appearing frequently
l1 = list()
from collections import Counter
a = Counter(frequency)
 
# Finding 3 highest values
high_500 = a.most_common(500)
 
 
 
print("top-500 Tags")

 
for i in high_500:
    l1.append(i[0])
    print(i[0])
# Out:
# top-500 Tags
# java
# javascript
# php
# c#
# python
# c++
# android
# html
# jquery
# mysql
# css
# c
# ios
# arrays
# r
# sql
# .net
# regex
# string
# objective-c
# swift
# json
# iphone
# asp.net
# sql-server
# bash
# python-3.x
# node.js
# linux
# list
# ajax
# xml
# ruby
# asp.net-mvc
# multithreading
# swing
# function
# windows
# database
# date
# mongodb
# angularjs
# html5
# xcode
# css3
# matlab
# pandas
# python-2.7
# eclipse
# wpf
# git
# algorithm
# winforms
# shell
# class
# excel
# c++11
# oracle
# ruby-on-rails
# sorting
# datetime
# object
# pointers
# file
# spring
# oop
# image
# dataframe
# variables
# vb.net
# linq
# generics
# jsf
# firebase
# angular
# numpy
# django
# loops
# forms
# sqlite
# dictionary
# scala
# mysqli
# performance
# visual-studio
# email
# matplotlib
# vba
# jsp
# apache-spark
# for-loop
# servlets
# macos
# if-statement
# facebook
# inheritance
# postgresql
# perl
# ecmascript-6
# nullpointerexception
# csv
# templates
# entity-framework
# ...

# %%
print(l1)
# Out:
# ['java', 'javascript', 'php', 'c#', 'python', 'c++', 'android', 'html', 'jquery', 'mysql', 'css', 'c', 'ios', 'arrays', 'r', 'sql', '.net', 'regex', 'string', 'objective-c', 'swift', 'json', 'iphone', 'asp.net', 'sql-server', 'bash', 'python-3.x', 'node.js', 'linux', 'list', 'ajax', 'xml', 'ruby', 'asp.net-mvc', 'multithreading', 'swing', 'function', 'windows', 'database', 'date', 'mongodb', 'angularjs', 'html5', 'xcode', 'css3', 'matlab', 'pandas', 'python-2.7', 'eclipse', 'wpf', 'git', 'algorithm', 'winforms', 'shell', 'class', 'excel', 'c++11', 'oracle', 'ruby-on-rails', 'sorting', 'datetime', 'object', 'pointers', 'file', 'spring', 'oop', 'image', 'dataframe', 'variables', 'vb.net', 'linq', 'generics', 'jsf', 'firebase', 'angular', 'numpy', 'django', 'loops', 'forms', 'sqlite', 'dictionary', 'scala', 'mysqli', 'performance', 'visual-studio', 'email', 'matplotlib', 'vba', 'jsp', 'apache-spark', 'for-loop', 'servlets', 'macos', 'if-statement', 'facebook', 'inheritance', 'postgresql
# ...

# %%
id = list()
id = Dataset3['id'].tolist()

# %%
print(len(id))
# Out:
# 676204

# %%
temp = 0

# %%
#counter = 0
#for i in range(0,len(l1)):
#  for j in range(0,len(tagshort2)):
#    for k in range(0,len(tagshort2[j])):
#      temp = tagshort2[j]
#      if(l1[i]==temp[k]):
#        counter = counter + 1
#        break
#        break
#      else:
#        k = k+1
#
#    j = j+1
#   
#i = i+1
#
#print(counter)

# %%
#counter = 0

#flag = 0
#for i in range(0,len(l1)): # i  = 0 - 499

 # for j in range(0,len(tagshort2)): # 0 - 676204
 #   if(flag[j]==0):
 #     temp = tagshort2[j]    
 #     for k in range(0,len(tagshort2[j])) :         
  #      if(l1[i]==temp[k]):
   #       counter = counter + 1     
  #        flag[k]=1     
  #        break
#
 #       else : continue
  #      break
   # else:
    #  continue
  

#print(counter)

# %%
#Question 9

# %%
counter=0
for i in range(len(tagshort2)):
  flag=0
  for j in range(500):
    if l1[j] in tagshort2[i] and flag==0:
      counter= counter+1
      flag=1
    else :
      continue

# %%
print(counter)
# Out:
# 662549

# %%
#total percentage of 500 tag
percentage=(counter*100)/len(tagshort2) 
print(percentage)
# Out:
# 97.98063897876972

# %%
#Question 10

# %%
counter2=0
for i in range(len(tagshort2)):
  flag=0
  for j in range(5000):
    if newList[j] in tagshort2[i] and flag==0:
      counter2 = counter2 + 1
      flag=1
    

print(counter2)
# Out:
# 641076

# %%
#total percentage of 5000 tag
percentage2=(counter*100)/len(tagshort2) 
print(percentage2)
# Out:
# 97.98063897876972
